# %% [markdown]
# ## Part 1 : Search in Google Images
#     Use tools and settings to set conditions for search.
#     Google Images shows 400 maximum of 700 images for a result i.e you can get maximum of 700 images for a class.
#     Make sure :
#         1. to mention exact size of images you want in size/exactly under tools section
#         2. to scroll till you get enough images for your dataset.
#
# ## Part 2 : Download files having URLs of all images shown in search result
#     Create a directory to save all files containing URLs.
#     Press Ctrl+Shift+J to open developer console. Copy and paste following script:
#
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
#
#      Press Enter to download the file having URLs of all images.
#      Rename the file with apt name(class name) and move it to folder created above.
#      Repeat above process till files of search result for all searches have been downloaded.
#
#
# ## Part 3 : Download Images Dataset

# %%
from fastai.vision import *
from pathlib import Path
import numpy as np

# %%
path=Path('/home/mobiliser/Python Scripts/DL/male female  db')

# %%
file='Data URLs/male'


folder='Data/male data'
dest=path/folder

# %%
#Uncomment this only when, you need to download:
#download_images(path/file, dest, max_pics=400)

# %%
classes=['male','female']

# %%
for c in classes:
    print(c)
    verify_images(path/'Data'/c, delete=True, max_size=400)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path/'Data', train=".", valid_pct=0.2,ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes,data.c
# Out:
# (['female', 'male'], 2)

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(16)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.812938</td>
#       <td>0.601285</td>
#       <td>0.358779</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.593048</td>
#       <td>0.382144</td>
#       <td>0.137405</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.458629</td>
#       <td>0.433968</td>
#       <td>0.114504</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.377578</td>
#       <td>0.441147</td>
#       <td>0.122137</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.311846</td>
#       <td>0.429925</td>
#       <td>0.114504</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
doc(download_images)

# %%
path=Path('/home/mobiliser/Python Scripts/DL')

# %%
ls=path.ls()

# %%
ls[0].ls()
# Out:
# [PosixPath('/home/mobiliser/Python Scripts/DL/male female  db/Notebooks'),
#  PosixPath('/home/mobiliser/Python Scripts/DL/male female  db/.ipynb_checkpoints'),
#  PosixPath('/home/mobiliser/Python Scripts/DL/male female  db/program_script.py'),
#  PosixPath('/home/mobiliser/Python Scripts/DL/male female  db/Creating image data-set from Google Images.ipynb'),
#  PosixPath('/home/mobiliser/Python Scripts/DL/male female  db/Learner.ipynb'),
#  PosixPath('/home/mobiliser/Python Scripts/DL/male female  db/Data URLs'),
#  PosixPath('/home/mobiliser/Python Scripts/DL/male female  db/Data'),
#  PosixPath('/home/mobiliser/Python Scripts/DL/male female  db/Data2')]

# %%
path.ls()
# Out:
# [PosixPath('/home/mobiliser/Python Scripts/DL/male female  db'),
#  PosixPath('/home/mobiliser/Python Scripts/DL/course-v3-master')]

# %%
from os import listdir

# %%
listdir(path/'male female  db')
# Out:
# ['Notebooks',
#  '.ipynb_checkpoints',
#  'program_script.py',
#  'Creating image data-set from Google Images.ipynb',
#  'Learner.ipynb',
#  'Data URLs',
#  'Data',
#  'Data2']

# %%
'fff/dsdsd'.rfind('/')
# Out:
# 3

# %%
import tkinter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-29b37e014535> in <module>
# ----> 1 import tkinter
#
# ModuleNotFoundError: No module named 'tkinter'
